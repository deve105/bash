# %%
https://ubco-biology.github.io/BIOL202/


https://towardsdatascience.com/my-workflow-for-open-and-reproducible-science-as-an-academic-researcher-in-biomedicine-b41eaabcd420

https://cyverse-snakemake-vice.readthedocs-hosted.com/en/latest/

https://nbis-reproducible-research.readthedocs.io/en/course_2104/git/


Webinar: Workflow Management Using Snakemake



https://anopheles-genomic-surveillance.github.io/workshop-3/about.html
Demonstration of R to analyze COVID 19 data using Google's CoLab



Snakemake #1 Writing your first Snakefile




]


Webinar: Workflow Management Using Snakemake



Biological Data Analytics Specialization


First find a sequence in blast
Spades for genome assembly
Prokka (comparing against existing annitations)

global and local alignment
mafft vs muscle vs clustal omega
(too slow for long sequences)
reference guided multiple sequence alignment

fasttree

quast work with spades

read mappers:
minimap2
unimap
BWA
bowtie2
etc

to obtain the consensus sequence 
an amplicon-based sequencing framework for accurately measuring intrhost virus diversity using primalseq and ivar

ViralMSA (minimap2 is a good option)

Markov chain
probability of the next state given the current state

dating a phylogeny
-treetime ancestral state reconstruction
-LSD2
-logdate

lineage or strain
-pangolin: decision tree
nextstrain
covariants: mutations and lineage over time
outbreak.info deaths, prevalence, etc


to find clusters
HIV trace transmission cluster engine
treecluster given a tree


https://github.com/SoyeonA/aBayesQR


https://github.com/mmatschiner


# Phylogenetics

https://github.com/amkozlov/raxml-ng

raxml-ng --all --msa 0823peruref_mafftaligned.fasta --model GTR+G --prefix T2 --threads 5


raxml-ng --all --msa testAA.fa --model LG+G8+F --tree pars{10} --bs-trees 200

Optimize branch lengths and free model parameters on a fixed topology

     (using multiple partitions with proportional branch lengths)

     ./raxml-ng --evaluate --msa testAA.fa --model partitions.txt --tree test.tree --brlen scaled

https://github.com/amkozlov/raxml-ng/wiki/Output:-files-and-settings

http://biopython.org/DIST/docs/tutorial/Tutorial.html

https://www.sciencedirect.com/science/article/abs/pii/S235230262300087X

http://tree.bio.ed.ac.uk/
https://www.hiv.lanl.gov/content/sequence/HIV/links.html


https://www.bali-phy.org/README.xhtml#ancestral_sequence_reconstruction

https://ben-redelings.org/

https://www.bali-phy.org/Tutorial4.html
https://www.bali-phy.org/


git clone https://github.com/veg/hyphy hyphy
cd hyphy
cmake .
make
#para salir
control +c

# %%
conda env list
#to activate pip2
conda activate pipdev2

# %%
https://uc-r.github.io/hc_clustering#kmeans_clustering

Matplotlib library
https://bio-bwa.sourceforge.net/
PacBio subreads were assembled into contigs using the PacBio de novo assembler Hierarchical Genome Assembly Process v4.0 (HGAP4)
http://sanger-pathogens.github.io/iva/
https://github.com/pauloluniyi/VGEA
https://github.com/dnanexus-archive/viral-ngs/wiki
https://viral-ngs.readthedocs.io/en/latest/reports.html
https://github.com/rcs333/VAPiD
https://academic.oup.com/bioinformatics/article/31/14/2374/254470
https://www.sciencedirect.com/science/article/pii/S1567134819303065?pes=vor
https://github.com/myl446/HivStudy
https://www.mdpi.com/1099-4300/22/2/255
